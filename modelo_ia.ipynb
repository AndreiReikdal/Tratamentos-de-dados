# %%
import os
import pandas as pd

# Importar bibliotecas
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# Carregar o arquivo CSV em um DataFrame (substitua pelo seu caminho real)
caminho_arquivo = (r'C:\\Users\Windows 10\\Downloads\\Desafios estagio IA\\tratamento_dados\\CSVDados.csv')
dados = pd.read_csv(caminho_arquivo)

# Selecionar os atributos numéricos
atributos = dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4']]

# Criar e treinar o modelo K-Means
n_grupos = 3
modelo_agrupamento = KMeans(n_clusters=n_grupos, random_state=42)

# Adicionar a coluna 'Categoria Prevista' ao DataFrame
dados['Categoria Prevista'] = modelo_agrupamento.fit_predict(atributos)

# Mapear os grupos para categorias
categorias = {0: 'Categoria A', 1: 'Categoria B', 2: 'Categoria C'}
dados['Categoria Prevista'] = dados['Categoria Prevista'].map(categorias)

# Calcular a precisão usando a coluna 'Grupo Previsto' como predição
precisao = accuracy_score(dados['Categoria'], dados['Grupo Previsto'])
print(f"Precisão do Modelo: {precisao * 100:.2f}%")

# Visualizar os atributos e a coluna de categorias
print("\nAtributos e Categoria Prevista:")
print(dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4', 'Categoria Prevista']])
print()

# %%
# Importar bibliotecas
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# Carregar o arquivo CSV em um DataFrame (substitua pelo seu caminho real)
caminho_arquivo = r'C:\\Users\Windows 10\\Downloads\\Desafios estagio IA\\tratamento_dados\\CSVDados.csv'
dados = pd.read_csv(caminho_arquivo)

# Selecionar os atributos numéricos
atributos = dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4']]

# Criar e treinar o modelo K-Means
n_grupos = 3
modelo_agrupamento = KMeans(n_clusters=n_grupos, random_state=42)
modelo_agrupamento.fit(atributos)

# Adicionar a coluna 'Categoria' ao DataFrame
dados['Categoria'] = modelo_agrupamento.predict(atributos)

# Calcular a precisão usando a coluna 'Categoria Prevista' como rótulo verdadeiro
precisao = accuracy_score(dados['Categoria'], dados['Categoria'])
print(f"Precisão do Modelo: {precisao * 100:.2f}%")

# Visualizar os atributos e as categorias previstas
print("\nAtributos e Categoria Prevista:")
print(dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4', 'Categoria']])
# Out:
# Precisão do Modelo: 100.00%
#
# Atributos e Categoria Prevista:
#      Atributo 1  Atributo 2  Atributo 3  Atributo 4  Categoria
# 0       325.635     223.475      89.390      12.770          1
# 1       312.865     191.550      89.390      12.770          1
# 2       300.095     204.320      83.005      12.770          1
# 3       293.710     197.935      95.775      12.770          1
# 4       319.250     229.860      89.390      12.770          1
# ..          ...         ...         ...         ...        ...
# 145     427.795     191.550     332.020     146.855          2
# 146     402.255     159.625     319.250     121.315          0
# 147     415.025     191.550     332.020     127.700          2
# 148     395.870     217.090     344.790     146.855          2
# 149     376.715     191.550     325.635     114.930          0
#
# [150 rows x 5 columns]

# %%
# Importar bibliotecas
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# Carregar o arquivo CSV em um DataFrame (substitua pelo seu caminho real)
caminho_arquivo = r'C:\\Users\Windows 10\\Downloads\\Desafios estagio IA\\tratamento_dados\\CSVDados.csv'
dados = pd.read_csv(caminho_arquivo)

# Selecionar os atributos numéricos
atributos = dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4']]

# Criar e treinar o modelo K-Means
n_grupos = 3
modelo_agrupamento = KMeans(n_clusters=n_grupos, random_state=42)
modelo_agrupamento.fit(atributos)

# Adicionar a coluna 'Categoria' ao DataFrame
dados['Categoria'] = modelo_agrupamento.predict(atributos)

# Mapear os valores numéricos para strings representando os grupos
dados['Categoria'] = dados['Categoria'].map({0: 'Grupo A', 1: 'Grupo B', 2: 'Grupo C'})

categorias = {0: 'Categoria A', 1: 'Categoria B', 2: 'Categoria C'}
d_categoria = dados['Categoria Prevista'].map(categorias)
print(d_categoria)

# Calcular a precisão usando a coluna 'Categoria' como rótulo verdadeiro
precisao = accuracy_score(dados['Categoria'], dados['Categoria'])
print(f"Precisão do Modelo: {precisao * 100:.2f}%")

# Visualizar os atributos e as categorias previstas
print("\nAtributos e Categoria Prevista:")
print(dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4', 'Categoria']])

# %%
# Importar bibliotecas
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# Carregar o arquivo CSV em um DataFrame (substitua pelo seu caminho real)
caminho_arquivo = r'C:\\Users\Windows 10\\Downloads\\Desafios estagio IA\\tratamento_dados\\CSVDados.csv'
dados = pd.read_csv(caminho_arquivo)

# Selecionar os atributos numéricos
atributos = dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4']]

# Criar e treinar o modelo K-Means
n_grupos = 3
modelo_agrupamento = KMeans(n_clusters=n_grupos, random_state=42)
modelo_agrupamento.fit(atributos)

# Adicionar a coluna 'Categoria' ao DataFrame
dados['Categoria'] = modelo_agrupamento.predict(atributos)

# Mapear os valores numéricos para strings representando os grupos
dados['Categoria'] = dados['Categoria'].map({0: 'Grupo A', 1: 'Grupo B', 2: 'Grupo C'})

# Calcular a precisão usando a coluna 'Categoria' como rótulo verdadeiro
precisao = accuracy_score(dados['Categoria'], dados['Categoria'])
print(f"Precisão do Modelo: {precisao * 100:.2f}%")

# Visualizar os atributos e as categorias previstas
print("\nAtributos e Categoria Prevista:")
print(dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4', 'Categoria']])

# Mapear os valores numéricos para strings representando as categorias previstas
categorias = {0: 'Categoria A', 1: 'Categoria B', 2: 'Categoria C'}
dados['Categoria Prevista'] = dados['Categoria'].map(categorias)

# Visualizar a coluna 'Categoria Prevista'
print("\nCategoria Prevista Mapeada:")
print(dados['Categoria Prevista'])

# %%
# Importar bibliotecas
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Carregar o arquivo CSV em um DataFrame (substitua pelo seu caminho real)
caminho_arquivo = r'C:\\Users\Windows 10\\Downloads\\Desafios estagio IA\\tratamento_dados\\CSVDados.csv'
dados = pd.read_csv(caminho_arquivo)

# Selecionar os atributos numéricos
atributos = dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4']]

# Criar e treinar o modelo K-Means no conjunto completo
n_grupos = 3
modelo_agrupamento = KMeans(n_clusters=n_grupos, random_state=42)
modelo_agrupamento.fit(atributos)

# Adicionar a coluna 'Categoria' ao DataFrame original
dados['Categoria'] = modelo_agrupamento.predict(atributos)

# Mapear os valores numéricos para strings representando os grupos
dados['Categoria'] = dados['Categoria'].map({0: 'Grupo A', 1: 'Grupo B', 2: 'Grupo C'})

# Visualizar os atributos e a categoria prevista
print("\nAtributos e Categoria Prevista:")
print(dados[['Atributo 1', 'Atributo 2', 'Atributo 3', 'Atributo 4', 'Categoria']])
# Out:
# Atributos e Categoria Prevista:
#      Atributo 1  Atributo 2  Atributo 3  Atributo 4 Categoria
# 0       325.635     223.475      89.390      12.770   Grupo B
# 1       312.865     191.550      89.390      12.770   Grupo B
# 2       300.095     204.320      83.005      12.770   Grupo B
# 3       293.710     197.935      95.775      12.770   Grupo B
# 4       319.250     229.860      89.390      12.770   Grupo B
# ..          ...         ...         ...         ...       ...
# 145     427.795     191.550     332.020     146.855   Grupo C
# 146     402.255     159.625     319.250     121.315   Grupo A
# 147     415.025     191.550     332.020     127.700   Grupo C
# 148     395.870     217.090     344.790     146.855   Grupo C
# 149     376.715     191.550     325.635     114.930   Grupo A
#
# [150 rows x 5 columns]

# %%
dados.to_csv(r'C:\\Users\Windows 10\\Downloads\\Desafios estagio IA\\tratamento_dados\\arquivo_modificado.csv', index=False)
